# %%
# %pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 960.0 kB/s eta 0:00:01
#    ------------------------------------- -- 276.5/294.9 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 3.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: mecab-python 0.996-ko-0.9.2-msvc has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of mecab-python or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = pd.read_csv("콜금리변동.csv", index_col=0)

# %%
x = x.iloc[:,:2]

# %%
df = x

# %%
del x

# %%
df
# Out:
#                 변환  원자료(콜금리)
# 20050103  20050103     3.270
# 20050104  20050104     3.270
# 20050105  20050105     3.280
# 20050106  20050106     3.210
# 20050107  20050107     3.220
# ...            ...       ...
# 20240725  20240725     3.557
# 20240726  20240726     3.541
# 20240729  20240729     3.505
# 20240730  20240730     3.513
# 20240731  20240731     3.530
#
# [4859 rows x 2 columns]

# %%
df.변환
# Out:
# 20050103    20050103
# 20050104    20050104
# 20050105    20050105
# 20050106    20050106
# 20050107    20050107
#               ...
# 20240725    20240725
# 20240726    20240726
# 20240729    20240729
# 20240730    20240730
# 20240731    20240731
# Name: 변환, Length: 4859, dtype: int64

# %%
x = df.변환
y = df["원자료(콜금리)"]

# %%
plt.xlabel("연도")
plt.ylabel("콜 금리")
plt.plot(x,y)
# Out:
# c:\Users\SesacPython\anaconda3\envs\nlp\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\SesacPython\anaconda3\envs\nlp\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\SesacPython\anaconda3\envs\nlp\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53084 (\N{HANGUL SYLLABLE KOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\SesacPython\anaconda3\envs\nlp\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\SesacPython\anaconda3\envs\nlp\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
df2 = pd.read_csv("콜금리test.csv", index_col=0)

# %%
df2 = df2.iloc[:-3, :]

# %%
df2
# Out:
#                Unnamed: 1  Unnamed: 2
# announce_date
# 20050215            3.260         0.0
# 20050310            3.260         0.0
# 20050407            3.230         0.0
# 20050512            3.300         0.0
# 20050609            3.280         0.0
# ...                   ...         ...
# 20240111            3.393         2.0
# 20240222            3.659         1.0
# 20240412            3.500         2.0
# 20240523            3.556         0.0
# 20240711            3.528         0.0
#
# [206 rows x 2 columns]

# %%
x, y = df2.index, df2["Unnamed: 1"]

# %%
y = list(y)

# %%
plt.plot(x,y)

# %%
x = pd.to_datetime(df2.index, format='%Y%m%d')

# %%
plt.plot(x,y)

# %%
base_interest_rate = pd.read_csv("기준금리test.csv", encoding='euc-kr')

# %%
base_interest_rate = base_interest_rate.iloc[:-3, :]

# %%
base_interest_rate
# Out:
#     announce_date       start         end  기준금리  변동
# 0      2005-02-15  2005-01-14  2005-02-14  3.25  동결
# 1      2005-03-10  2005-02-16  2005-03-09  3.25  동결
# 2      2005-04-07  2005-03-11  2005-04-06  3.25  동결
# 3      2005-05-12  2005-04-08  2005-05-11  3.25  동결
# 4      2005-06-09  2005-05-13  2005-06-08  3.25  동결
# ..            ...         ...         ...   ...  ..
# 201    2024-01-11  2023-12-01  2024-01-10  3.50  동결
# 202    2024-02-22  2024-01-12  2024-02-21  3.50  동결
# 203    2024-04-12  2024-02-23  2024-04-11  3.50  동결
# 204    2024-05-23  2024-04-13  2024-05-22  3.50  동결
# 205    2024-07-11  2024-05-24  2024-07-10  3.50  동결
#
# [206 rows x 5 columns]

# %%
x2 = pd.to_datetime(list(base_interest_rate.announce_date)).strftime('%Y%m%d')
x2 = pd.to_datetime(x2, format='%Y%m%d')
y2 = base_interest_rate.기준금리

# %%
plt.figure(figsize=(103,5))
plt.rcParams['font.family'] ='NanumGothic'
plt.rcParams['axes.unicode_minus'] =False
plt.plot(x, y, 'b', marker='o', markersize=3, linestyle = '--', alpha=0.5)
plt.plot(x2, y2, 'r', marker= '*', markersize=5, alpha=0.5)
plt.plot(x2, y3, 'g')
plt.legend(('콜금리', '기준금리'))

plt.plot(a,b, color="tab:purple")

plt.show()

# %%
df
# Out:
#                 변환  원자료(콜금리)
# 20050103  20050103     3.270
# 20050104  20050104     3.270
# 20050105  20050105     3.280
# 20050106  20050106     3.210
# 20050107  20050107     3.220
# ...            ...       ...
# 20240725  20240725     3.557
# 20240726  20240726     3.541
# 20240729  20240729     3.505
# 20240730  20240730     3.513
# 20240731  20240731     3.530
#
# [4859 rows x 2 columns]

# %%
df3 = pd.read_csv("콜금리test.csv")

# %%
y3 = df3["Unnamed: 3"]

# %%
df
# Out:
#                 변환  원자료(콜금리)
# 20050103  20050103     3.270
# 20050104  20050104     3.270
# 20050105  20050105     3.280
# 20050106  20050106     3.210
# 20050107  20050107     3.220
# ...            ...       ...
# 20240725  20240725     3.557
# 20240726  20240726     3.541
# 20240729  20240729     3.505
# 20240730  20240730     3.513
# 20240731  20240731     3.530
#
# [4859 rows x 2 columns]

# %%
a = pd.to_datetime(df.index, format='%Y%m%d')

# %%
b = df['원자료(콜금리)']

# %%
plt.plot(a,b)
